# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import pandas as pd
import threading 
import dtw
import datetime
from time import sleep

# %%
#https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-search-trends.md
  #  https://pair-code.github.io/covid19_symptom_dataset/?country=NZ&symptom=insomnia

# %%
# %config Completer.use_jedi = False
pytrends = TrendReq(hl='en-US', tz=360)
#pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25), proxies=['https://34.203.233.13:80',], retries=2, backoff_factor=0.1, requests_args={'verify':False})

# %%
#setting up a symptomps array:
filename = "2020_country_weekly_2020_GB_weekly_symptoms_dataset.csv";
data = pd.read_csv(filename).sort_values('date').groupby(['date']).mean()

# %%
filename = "usa.csv";
data2 = pd.read_csv(filename)[['Date', '7-Day Moving Avg']].iloc[::-1]
data2 = data2.set_index('Date')

data2.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data = data.drop(['sub_region_2', 'sub_region_2_code'], axis=1)
data.columns = data.columns.map(lambda x: x.replace("symptom:", ""))
symptoms = data.columns

# %%
data
# Out:
#             Abdominal obesity  Abdominal pain       Acne  Actinic keratosis  \
# date
# 2020-01-06           3.641711        6.941382   9.356974           0.473082
# 2020-01-13           3.460461        6.794605   9.208026           0.504797
# 2020-01-20           3.365987        6.806579   9.341579           0.469320
# 2020-01-27           3.155364        6.931711   9.065395           0.494662
# 2020-02-03           3.200987        6.798289   9.403355           0.499732
# 2020-02-10           2.852697        6.675461   8.886184           0.477551
# 2020-02-17           3.058158        7.335197   9.690987           0.531824
# 2020-02-24           2.886490        7.207237   9.205789           0.493151
# 2020-03-02           2.839079        6.645197   9.003487           0.483611
# 2020-03-09           2.412053        6.880987   8.215395           0.427635
# 2020-03-16           1.708467        5.324803   6.912961           0.317410
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 2020-01-06 to 2020-12-07
# Columns: 422 entries, Abdominal obesity to pancreatitis
# dtypes: float64(422)
# memory usage: 163.0+ KB

# %%
data.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data[data.index < '2020-06-01'].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data.loc[:, ~(data < 10).all()]
# Out:
#             sub_region_2  sub_region_2_code  symptom:Acne  symptom:Allergy  \
# date
# 2020-01-06           NaN                NaN      9.356974        10.163026
# 2020-01-13           NaN                NaN      9.208026         9.969737
# 2020-01-20           NaN                NaN      9.341579        10.079671
# 2020-01-27           NaN                NaN      9.065395        10.295987
# 2020-02-03           NaN                NaN      9.403355        10.280921
# 2020-02-10           NaN                NaN      8.886184        10.109934
# 2020-02-17           NaN                NaN      9.690987        10.311184
# 2020-02-24           NaN                NaN      9.205789        10.271250
# 2020-03-02           NaN                NaN      9.003487        10.643487
# 2020-03-09           NaN                NaN      8.215395        10.982566
# 2020-03-16           NaN                NaN      6.912961        11.350066
# ...

# %%
len(data)
# Out:
# 49

# %%
for symptom in symptoms:
    pytrends.build_payload([symptom], cat=0, timeframe='2020-01-01 2020-12-07', geo='US', gprop='')
    if  symptom_trends.empty:
        symptom_trends = pytrends.interest_over_time()
    else:
        symptom_trends[symptom] = pytrends.interest_over_time()[symptom].values
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-24-7e8eb6231e09> in <module>
#       2 kw_list = data.columns.map(lambda x: x.replace("symptom:", ""))[2:]
#       3 for kw in kw_list:
# ----> 4     pytrends.build_payload([kw], cat=0, timeframe='2019-11-30 2020-12-07', geo='', gprop='')
#       5     if  overtime.empty:
#       6         overtime = pytrends.interest_over_time()
#
# ~\.conda\envs\int\lib\site-packages\pytrends\request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     167         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     168         # get tokens
# --> 169         self._tokens()
#     170         return
#     171
#
# ~\.conda\envs\int\lib\site-packages\pytrends\request.py in _tokens(self)
# ...

# %%
pytrends.build_payload(['COVID', 'coronavirus'], cat=0, timeframe='2020-01-01 2020-12-07', geo='US', gprop='')
pytrends.interest_over_time().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
overtime
# Out:
#             Abdominal pain  isPartial  Abdominal obesity  Acne  \
# date
# 2019-12-01              89      False                 35    78
# 2019-12-08              87      False                 12    75
# 2019-12-15              79      False                 47    75
# 2019-12-22              88      False                 13    83
# 2019-12-29              92      False                 12    86
# 2020-01-05              91      False                 68    86
# 2020-01-12              92      False                 54    82
# 2020-01-19              96      False                 22    82
# 2020-01-26              86      False                 33    79
# 2020-02-02              89      False                 55    80
# 2020-02-09              91      False                 66    80
# 2020-02-16              90      False                 87    81
# 2020-02-23              97      False                 32    82
# 2020-03-01              94      False                 74    77
# ...

# %%
overtime['dry eyes'].values
# Out:
# array([ 79,  81,  81,  71,  85,  92,  78,  88, 100, 100,  90,  93,  92,
#         93,  91,  70,  78,  76,  82,  89,  81,  78,  85,  73,  78,  72,
#         79,  85,  82,  89,  82,  78,  80,  82,  84,  83,  85,  83,  80,
#         82,  90,  82,  81,  77,  89,  85,  86,  86,  76,  93,  99,  77,
#         78])

# %%
overtime.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pytrends.get_historical_interest(kw_list, year_start=2020, month_start=1, day_start=1, hour_start=0, year_end=2018, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-20166a6e33e8> in <module>
# ----> 1 pytrends.get_historical_interest(kw_list, year_start=2018, month_start=1, day_start=1, hour_start=0, year_end=2021, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
#
# ~\Miniconda3\envs\int\lib\site-packages\pytrends\request.py in get_historical_interest(self, keywords, year_start, month_start, day_start, hour_start, year_end, month_end, day_end, hour_end, cat, geo, gprop, sleep)
#     503             try:
#     504                 self.build_payload(keywords, cat, tf, geo, gprop)
# --> 505                 week_df = self.interest_over_time()
#     506                 df = df.append(week_df)
#     507             except Exception as e:
#
# ~\Miniconda3\envs\int\lib\site-packages\pytrends\request.py in interest_over_time(self)
#     210
# ...

# %%
acne = data['Acne']
acne.values
# Out:
# array([ 9.35697368,  9.20802632,  9.34157895,  9.06539474,  9.40335526,
#         8.88618421,  9.69098684,  9.20578947,  9.00348684,  8.21539474,
#         6.91296053,  8.49493421, 10.89427632, 11.11006579, 12.93546053,
#        13.13072368, 13.76657895, 12.96565789, 14.48131579, 12.03256579,
#        11.09592105, 11.74493421, 12.49052632, 11.36888158, 10.94644737,
#        11.56914474, 11.25217105, 12.27460526, 11.49947368, 10.9275    ,
#        10.73282895, 10.54111111, 10.73666667, 10.43267974, 10.56934641,
#        10.08947712,  9.76614379,  9.68092105,  9.73071895,  9.46941176,
#         9.56934211,  9.70467105,  9.78302632,  9.55243421,  9.88111111,
#         9.59960526,  9.51      ,  9.10059211,  9.05506579])

# %%
# Import the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Comment out the following line if you are using Jupyter Notebook
# %matplotlib inline
# Use a predefined style set
plt.style.use('ggplot')

# Import Faker
from faker import Faker
fake = Faker()

# To ensure the results are reproducible
Faker.seed()

names_list = []

fake = Faker()
for _ in range(100):
  names_list.append(fake.name())

# To ensure the results are reproducible
np.random.seed(7)

salaries = []
for _ in range(100):
    salary = np.random.randint(1000,2500)
    salaries.append(salary)

# Create pandas DataFrame
salary_df = pd.DataFrame(
    {'date': acne.index,
     'value': acne.values
    })

# Print a subsection of the DataFrame
print(salary_df.head())
# Out:
#          date     value
# 0  2020-01-06  9.356974
# 1  2020-01-13  9.208026
# 2  2020-01-20  9.341579
# 3  2020-01-27  9.065395
# 4  2020-02-03  9.403355

# %%
# First assign all the instances to 
salary_df['class'] = 0

# Manually edit the labels for the anomalies
salary_df.at[16, 'class'] = 1

# Veirfy 
print(salary_df)
# Out:
#           date      value  class
# 0   2020-01-06   9.356974      0
# 1   2020-01-13   9.208026      0
# 2   2020-01-20   9.341579      0
# 3   2020-01-27   9.065395      0
# 4   2020-02-03   9.403355      0
# 5   2020-02-10   8.886184      0
# 6   2020-02-17   9.690987      0
# 7   2020-02-24   9.205789      0
# 8   2020-03-02   9.003487      0
# 9   2020-03-09   8.215395      0
# 10  2020-03-16   6.912961      0
# 11  2020-03-23   8.494934      0
# 12  2020-03-30  10.894276      0
# 13  2020-04-06  11.110066      0
# 14  2020-04-13  12.935461      0
# 15  2020-04-20  13.130724      0
# 16  2020-04-27  13.766579      1
# 17  2020-05-04  12.965658      0
# 18  2020-05-11  14.481316      0
# 19  2020-05-18  12.032566      0
# 20  2020-05-25  11.095921      0
# 21  2020-06-01  11.744934      0
# 22  2020-06-08  12.490526      0
# 23  2020-06-15  11.368882      0
# 24  2020-06-22  10.946447      0
# 25  2020-06-29  11.569145      0
# 26  2020-07-06  11.252171      0
# ...

# %%
from pyod.models.knn import KNN
# Segregate the salary values and the class labels 
X = salary_df['value'].values.reshape(-1,1)
y = salary_df['class'].values

# Train kNN detector
clf = KNN(contamination=0.02, n_neighbors=5)
clf.fit(X)
# Out:
# KNN(algorithm='auto', contamination=0.02, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
# Get the prediction labels of the training data
y_train_pred = clf.labels_ 
    
# Outlier scores
y_train_scores = clf.decision_scores_

# Import the utility function for model evaluation
from pyod.utils import evaluate_print

# Evaluate on the training data
evaluate_print('KNN', y, y_train_scores)
# Out:
# KNN ROC:0.9583, precision @ rank n:0.0

# %%
# A salary of $37 (an anomaly right?)
X_test = np.array([[37.]])
# Check what the model predicts on the given test data point
clf.predict(X_test)
# Out:
# array([1])

# %%
# A salary of $1256
X_test_abnormal = np.array([[11.]])

# Predict
clf.predict(X_test_abnormal)
# Out:
# array([0])

# %%
import numpy as np
import matplotlib.pyplot as plt

# multiply and add by random numbers to get some real values
# Function to Detection Outlier on one-dimentional datasets.
def find_anomalies(data):
    #define a list to accumlate anomalies
    anomalies = []
    mid = 100
    # Set upper and lower limit to 3 standard deviation
    random_data_std = np.std(data.values)
    random_data_mean = np.mean(data.values)
    anomaly_cut_off = random_data_std * 2
    
    lower_limit  = random_data_mean - anomaly_cut_off 
    upper_limit = random_data_mean + anomaly_cut_off
    # print(random_data_std)
    # print(random_data_mean)
    # print(upper_limit)
    # print(lower_limit)
    # Generate outliers
    for outlier in data:
        if outlier > upper_limit:
            anomalies.append(outlier)
    return anomalies

# %%
test = data['Trichoptilosis']
#len(find_anomalies(test)) / len(test)
find_anomalies(test)
# Out:
# [146.17384901487222, 148.48934753682542, 151.2806270778544]

# %%
data['Yawn'].mean()
# Out:
# 0.2398078407514562

# %%
def normalize(row):
    maxim = np.max(row)
    multi = 1
    return row.apply(lambda x: round(x*multi))

# %%
transposed = data.transpose()
data.apply(lambda row: normalize(row)).plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
transposed = data.apply(lambda row: normalize(row)).transpose()
#transposed.apply(lambda x: x if (len(find_anomalies(x)) > 2) else None, axis = 1).dropna().transpose()
filtered = transposed.apply(lambda row: row if len(find_anomalies(row)) > 2 else row.apply(lambda x: None), axis = 1).dropna()
filtered['anomalies'] = filtered.apply(lambda row: len(find_anomalies(row)), axis=1).transpose()
filtered['coeff'] = filtered.mean(axis=1).transpose()
filtered = filtered.sort_values('anomalies').transpose()
filtered
# Out:
# <ipython-input-275-15336400343b>:13: RuntimeWarning: divide by zero encountered in double_scalars
#   multi = 100 / random_data_mean
#             Fever  Croup  Cramp  Cough  Hay fever  Common cold  Coma  \
# date
# 2020-01-06    5.0   0.00    4.0  10.00       1.00        14.00  0.00
# 2020-01-13    5.0   0.00    4.0   8.00       1.00        13.00  0.00
# 2020-01-20    5.0   0.00    4.0   9.00       1.00        18.00  0.00
# 2020-01-27    6.0   0.00    4.0   9.00       1.00        26.00  0.00
# 2020-02-03    6.0   0.00    4.0   9.00       1.00        20.00  0.00
# 2020-02-10    6.0   0.00    4.0  10.00       1.00        23.00  0.00
# 2020-02-17    5.0   0.00    4.0   9.00       1.00        16.00  0.00
# 2020-02-24    7.0   0.00    4.0  10.00       1.00        26.00  0.00
# 2020-03-02    8.0   0.00    4.0  11.00       2.00        31.00  0.00
# 2020-03-09   23.0   1.00    4.0  19.00       2.00        50.00  0.00
# 2020-03-16   32.0   1.00    3.0  24.00       2.00        53.00  0.00
# ...

# %%
before = filtered.transpose().sort_values('coeff').iloc[::-1]
before
# Out:
# date                                      2020-01-06  2020-01-13  2020-01-20  \
# Infection                                       36.0        31.0        36.0
# Common cold                                     14.0        13.0        18.0
# Allergy                                         10.0        10.0        10.0
# Fever                                            5.0         5.0         5.0
# Arthritis                                        7.0         7.0         7.0
# Cough                                           10.0         8.0         9.0
# Xeroderma                                        3.0         4.0         4.0
# Cramp                                            4.0         4.0         4.0
# Dementia                                         4.0         4.0         5.0
# Candidiasis                                      4.0         4.0         4.0
# Anemia                                           4.0         4.0         4.0
# ...

# %%
sorted_coeffs = before.transpose().rename(columns={"Cough": "Rash on skin", "Infection": "Cough", "Allergy": "Loss of taste or smell", "Common cold": "Tiredness", "Xeroderma": "Sore throat", "Cramp": "Chest pain", "Arthritis": "Headache", "Dementia": "Diarrhoea", "Candidiasis": "Conjunctivitis"}).transpose()

# %%
sorted_coeffs.head(10)[['coeff']]
# Out:
# date                    coeff
# Cough                   33.72
# Tiredness               14.42
# Loss of taste or smell  11.12
# Fever                    7.30
# Headache                 7.04
# Rash on skin             6.88
# Sore throat              4.58
# Chest pain               4.00
# Diarrhoea                3.38
# Conjunctivitis           3.26
